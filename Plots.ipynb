# %%
import matplotlib.pyplot as plt

names = ["EL", "RU", "JP", "TH", "EL_r", "RU_r", "JP_r", "TH_r"]
x_BLEU = [28.84, 17.9, 8.61, 17.18, 29.49, 18.04, 5.1, 3.87]
y_BLEU = [14.14, 13.47, 12.2, 13.66, 14.11, 13.72, 9.11, 6.48]

x_PPL = [10.4458, 17.17423, 30.77808, 19.22, 10.39494, 18.49718, 52.92114, 135.19739]
y_PPL = [38.54249, 40.0627, 43.77967, 42.3079, 37.97577, 39.88107, 49.31154, 71.74496]

plt.figure(1)

for i in range(8):
    plt.scatter(x_BLEU[i], y_BLEU[i], label=names[i])

plt.xlabel("BLEU to english")
plt.ylabel("BLEU transfer learned")

plt.figure(2)

for i in range(8):
    plt.scatter(x_PPL[i], y_PPL[i], label=names[i])

plt.xlabel("PPL to english")
plt.ylabel("PPL transfer learned")

plt.figure(3)

for i in range(7):
    plt.scatter(x_PPL[i], y_PPL[i], label=names[i])

plt.xlabel("PPL to english")
plt.ylabel("PPL transfer learned")

plt.legend()
plt.show()
